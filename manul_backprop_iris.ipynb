# %% [markdown]
# #### Iris species prediction

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# %%
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
    print("Using Apple's MPS")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using CUDA gpu: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print(f"Using cpu")
print(f"Device is: {device}")
# Out:
# Using Apple's MPS
# Device is: mps

# %%
df = pd.read_csv("data/iris/Iris.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.drop(columns=["Id"], inplace=True )

# %%
'''
This is a very powerful python library for exploratory data analysis. Open the iris.html file in a browser to see the report. It was generated using the ydata_profiling library. Using just simple commands, we can generate a comprehensive report of the dataset. Do use it whenever you are working with a new dataset in ML.
'''
profile = ProfileReport(df, title="Exploratory Data Analysis", explorative=True)
profile.to_file("iris_report.html")
# Out:
# Summarize dataset:  30%|███       | 3/10 [00:00<00:00, 146.77it/s, Describe variable: Species]
# 100%|██████████| 5/5 [00:00<00:00, 89621.88it/s]
# Summarize dataset: 100%|██████████| 30/30 [00:00<00:00, 48.38it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 687.14it/s]

# %% [markdown]
# #### Neural Network with manual backpropagation

# %%
'''
We will make a Neural network with just one hidden layer for simplicity.
'''

# %%
df.sample(10)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 68             6.2           2.2            4.5           1.5  Iris-versicolor
# 36             5.5           3.5            1.3           0.2      Iris-setosa
# 104            6.5           3.0            5.8           2.2   Iris-virginica
# 39             5.1           3.4            1.5           0.2      Iris-setosa
# 37             4.9           3.1            1.5           0.1      Iris-setosa
# 75             6.6           3.0            4.4           1.4  Iris-versicolor
# 24             4.8           3.4            1.9           0.2      Iris-setosa
# 31             5.4           3.4            1.5           0.4      Iris-setosa
# 52             6.9           3.1            4.9           1.5  Iris-versicolor
# 102            7.1           3.0            5.9           2.1   Iris-virginica

# %%
df = shuffle(df).reset_index(drop=True)
X, y = df.drop(["Species"], axis=1), df["Species"]

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.2)

# %%
std_scalar = ColumnTransformer(transformers=[("std_scaler", StandardScaler(), [0,1,2,3])])
x_pipeline = Pipeline([('std_scalar', std_scalar)])
x_pipeline.fit(train_x)
# Out:
# Pipeline(steps=[('std_scalar',
#                  ColumnTransformer(transformers=[('std_scaler',
#                                                   StandardScaler(),
#                                                   [0, 1, 2, 3])]))])

# %%
train_x = torch.tensor(x_pipeline.transform(train_x),dtype=torch.float32)
test_x = torch.tensor(x_pipeline.transform(test_x),dtype=torch.float32)

# %%
y_enc = LabelEncoder()
y_enc.fit(train_y)
# Out:
# LabelEncoder()

# %%
train_y = torch.tensor(y_enc.transform(train_y))
test_y = torch.tensor(y_enc.transform(test_y))

# %%
def cmp(name, manual_grad, torch_grad):
    exact = torch.all(manual_grad == torch_grad).item()
    appx = torch.allclose(manual_grad, torch_grad)
    # print(f"{name} - Exact: {exact}, Approx: {appx}")
    return exact or appx

# %%
class NNModel():
    def __init__(self, n_input, n_output, n_hidden):
        self.w1 = torch.nn.Parameter(torch.empty(n_input, n_hidden), requires_grad=True)
        self.b1 = torch.nn.Parameter(torch.empty(n_hidden), requires_grad=True)
        self.w2 = torch.nn.Parameter(torch.empty(n_hidden, n_output), requires_grad=True)
        self.b2 = torch.nn.Parameter(torch.empty(n_output), requires_grad=True)

        nn.init.kaiming_normal_(self.w1)
        nn.init.normal_(self.b1)
        nn.init.kaiming_normal_(self.w2)
        nn.init.normal_(self.b2)

    def forward(self, x):
        self.layer_1_preact = torch.matmul(x, self.w1) + self.b1
        self.layer_1_act = self.layer_1_preact.relu()
        self.logits = torch.matmul(self.layer_1_act, self.w2) + self.b2

        return self.logits

    def parameters(self):
        return [self.w1, self.b1, self.w2, self.b2]

# %%
n_features = 4
n_classes = 3
n_hidden_neurons = 10
epochs = 100
lr = 0.5

# %%
model = NNModel(n_features, n_classes, n_hidden_neurons)

# %%
# Training loop
for epoch in range(epochs):
    # forward pass
    out_logits = model.forward(train_x)

    # compute loss
    exp_logits = out_logits.exp()
    total_outlogits = exp_logits.sum(dim=1, keepdim=True)
    total_outlogits_inv = total_outlogits.pow(-1)
    prob = exp_logits*total_outlogits_inv

    log_prob = prob.log()
    loss = -log_prob[[i for i in range(len(log_prob))], train_y].mean()

    print(f"Epoch {epoch+1}/{epochs}: Train Loss: {loss.item():.4f}")

    intermediate_op = [out_logits,exp_logits,total_outlogits,total_outlogits_inv, prob, log_prob, model.layer_1_preact, model.layer_1_act, model.logits]
    for op in intermediate_op:
        op.retain_grad()

    # backward pass
    for p in model.parameters():
        p.grad = None  # reset gradients

    # Pytorch gradient calculation
    loss.backward()

    # Manual gradient calculation
    with (torch.no_grad()):
        dlog_prob = torch.zeros_like(log_prob)
        dlog_prob[[i for i in range(len(log_prob))], train_y] = -1/len(log_prob)
        dprob = torch.pow(prob, -1) * dlog_prob
        dexp_logits = total_outlogits_inv * dprob
        dtotal_outlogits_inv = (exp_logits * dprob).sum(dim=1, keepdim=True)
        dtotal_outlogits = -total_outlogits.pow(-2) * dtotal_outlogits_inv
        dexp_logits += dtotal_outlogits
        dlogits = exp_logits * dexp_logits
        dw2 = torch.matmul(model.layer_1_act.T, dlogits)
        db2 = dlogits.sum(dim=0)
        dlayer_1_act = torch.matmul(dlogits, model.w2.T)
        mask = torch.ones_like(dlayer_1_act).masked_fill(model.layer_1_preact < 0.0, 0.0)
        dlayer_1_preact = dlayer_1_act * mask
        dw1 = torch.matmul(train_x.T, dlayer_1_preact)
        db1 = dlayer_1_preact.sum(dim=0)

        comparison_list = []
        comparison_list.append(cmp("loss", dlog_prob, log_prob.grad))
        comparison_list.append(cmp("prob", dprob, prob.grad))
        comparison_list.append(cmp("total_outlogits_inv", dtotal_outlogits_inv, total_outlogits_inv.grad))
        comparison_list.append(cmp("total_outlogits", dtotal_outlogits, total_outlogits.grad))
        comparison_list.append(cmp("exp_logits", dexp_logits, exp_logits.grad))
        comparison_list.append(cmp("logits", dlogits, model.logits.grad))
        comparison_list.append(cmp("w2", dw2, model.w2.grad))
        comparison_list.append(cmp("b2", db2, model.b2.grad))
        comparison_list.append(cmp("layer_1_act", dlayer_1_act, model.layer_1_act.grad))
        comparison_list.append(cmp("layer_1_preact", dlayer_1_preact, model.layer_1_preact.grad))
        comparison_list.append(cmp("w1", dw1, model.w1.grad))
        comparison_list.append(cmp("b1", db1, model.b1.grad))

        if not all(comparison_list):
            print("Some gradients do not match!")

        # print(f"All gradients match: {all(comparison_list)}")

    # manual parameter update
    with torch.no_grad():
        model.w1 -= lr * dw1
        model.b1 -= lr * db1
        model.w2 -= lr * dw2
        model.b2 -= lr * db2

    # update parameters using pytorch
    # for p in model.parameters():
    #     p.data -= lr*p.grad

    # Test validation loss
    with torch.no_grad():
        val_labels = model.forward(test_x)
        val_loss = F.cross_entropy(val_labels, test_y, reduction='mean').item()
        print(f"Validation loss: {val_loss:.4f}")
        val_accuracy = (val_labels.argmax(dim=1) == test_y).float().mean().item()
        print(f"Validation accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/100: Train Loss: 3.0052
# Validation loss: 0.7631
# Validation accuracy: 0.6667
# Epoch 2/100: Train Loss: 0.6442
# Validation loss: 0.5100
# Validation accuracy: 0.7333
# Epoch 3/100: Train Loss: 0.4405
# Validation loss: 0.3965
# Validation accuracy: 0.8333
# Epoch 4/100: Train Loss: 0.3530
# Validation loss: 0.3529
# Validation accuracy: 0.8333
# Epoch 5/100: Train Loss: 0.3150
# Validation loss: 0.3176
# Validation accuracy: 0.9000
# Epoch 6/100: Train Loss: 0.2870
# Validation loss: 0.2908
# Validation accuracy: 0.9333
# Epoch 7/100: Train Loss: 0.2646
# Validation loss: 0.2683
# Validation accuracy: 0.9333
# Epoch 8/100: Train Loss: 0.2457
# Validation loss: 0.2495
# Validation accuracy: 0.9333
# Epoch 9/100: Train Loss: 0.2295
# Validation loss: 0.2333
# Validation accuracy: 0.9333
# Epoch 10/100: Train Loss: 0.2154
# Validation loss: 0.2193
# Validation accuracy: 0.9333
# Epoch 11/100: Train Loss: 0.2029
# Validation loss: 0.2070
# Validation accuracy: 0.9333
# Epoch 12/100: Train Loss: 0.1918
# Validation loss: 0.1962
# Validation accuracy: 0.9667
# Epoch 13/100: Train Loss: 0.1819
# Validation loss: 0.1866
# Validation accuracy: 0.9667
# Epoch 14/100: Train Loss: 0.1730
# Validation loss: 0.1780
# Validation accuracy: 0.9667
# Epoch 15/100: Train Loss: 0.1649
# Validation loss: 0.1704
# Validation accuracy: 0.9667
# Epoch 16/100: Train Loss: 0.1576
# Validation loss: 0.1634
# Validation accuracy: 0.9667
# Epoch 17/100: Train Loss: 0.1509
# Validation loss: 0.1571
# Validation accuracy: 0.9667
# Epoch 18/100: Train Loss: 0.1448
# Validation loss: 0.1514
# Validation accuracy: 0.9667
# Epoch 19/100: Train Loss: 0.1392
# Validation loss: 0.1463
# Validation accuracy: 0.9667
# Epoch 20/100: Train Loss: 0.1340
# Validation loss: 0.1415
# Validation accuracy: 0.9667
# Epoch 21/100: Train Loss: 0.1292
# Validation loss: 0.1372
# Validation accuracy: 0.9667
# Epoch 22/100: Train Loss: 0.1248
# Validation loss: 0.1333
# Validation accuracy: 0.9667
# Epoch 23/100: Train Loss: 0.1207
# Validation loss: 0.1297
# Validation accuracy: 0.9667
# Epoch 24/100: Train Loss: 0.1170
# Validation loss: 0.1264
# Validation accuracy: 0.9667
# Epoch 25/100: Train Loss: 0.1134
# Validation loss: 0.1233
# Validation accuracy: 0.9667
# Epoch 26/100: Train Loss: 0.1102
# Validation loss: 0.1205
# Validation accuracy: 0.9667
# Epoch 27/100: Train Loss: 0.1071
# Validation loss: 0.1179
# Validation accuracy: 0.9667
# Epoch 28/100: Train Loss: 0.1043
# Validation loss: 0.1155
# Validation accuracy: 0.9667
# Epoch 29/100: Train Loss: 0.1016
# Validation loss: 0.1132
# Validation accuracy: 0.9667
# Epoch 30/100: Train Loss: 0.0991
# Validation loss: 0.1111
# Validation accuracy: 0.9667
# Epoch 31/100: Train Loss: 0.0968
# Validation loss: 0.1092
# Validation accuracy: 0.9667
# Epoch 32/100: Train Loss: 0.0946
# Validation loss: 0.1074
# Validation accuracy: 0.9667
# Epoch 33/100: Train Loss: 0.0925
# Validation loss: 0.1057
# Validation accuracy: 0.9667
# Epoch 34/100: Train Loss: 0.0906
# Validation loss: 0.1041
# Validation accuracy: 0.9667
# Epoch 35/100: Train Loss: 0.0888
# Validation loss: 0.1026
# Validation accuracy: 0.9667
# Epoch 36/100: Train Loss: 0.0871
# Validation loss: 0.1012
# Validation accuracy: 0.9667
# Epoch 37/100: Train Loss: 0.0854
# Validation loss: 0.0999
# Validation accuracy: 0.9667
# Epoch 38/100: Train Loss: 0.0839
# Validation loss: 0.0987
# Validation accuracy: 0.9667
# Epoch 39/100: Train Loss: 0.0824
# Validation loss: 0.0976
# Validation accuracy: 0.9667
# Epoch 40/100: Train Loss: 0.0811
# Validation loss: 0.0965
# Validation accuracy: 0.9667
# Epoch 41/100: Train Loss: 0.0797
# Validation loss: 0.0955
# Validation accuracy: 0.9667
# Epoch 42/100: Train Loss: 0.0785
# Validation loss: 0.0945
# Validation accuracy: 0.9667
# Epoch 43/100: Train Loss: 0.0773
# Validation loss: 0.0936
# Validation accuracy: 0.9667
# Epoch 44/100: Train Loss: 0.0762
# Validation loss: 0.0928
# Validation accuracy: 0.9667
# Epoch 45/100: Train Loss: 0.0751
# Validation loss: 0.0920
# Validation accuracy: 0.9667
# Epoch 46/100: Train Loss: 0.0741
# Validation loss: 0.0912
# Validation accuracy: 0.9667
# Epoch 47/100: Train Loss: 0.0731
# Validation loss: 0.0905
# Validation accuracy: 0.9667
# Epoch 48/100: Train Loss: 0.0722
# Validation loss: 0.0898
# Validation accuracy: 0.9667
# Epoch 49/100: Train Loss: 0.0713
# Validation loss: 0.0891
# Validation accuracy: 0.9667
# Epoch 50/100: Train Loss: 0.0704
# Validation loss: 0.0885
# Validation accuracy: 0.9667
# Epoch 51/100: Train Loss: 0.0696
# Validation loss: 0.0879
# Validation accuracy: 0.9667
# Epoch 52/100: Train Loss: 0.0688
# Validation loss: 0.0873
# Validation accuracy: 0.9667
# Epoch 53/100: Train Loss: 0.0680
# Validation loss: 0.0868
# Validation accuracy: 0.9667
# Epoch 54/100: Train Loss: 0.0673
# Validation loss: 0.0863
# Validation accuracy: 0.9667
# Epoch 55/100: Train Loss: 0.0666
# Validation loss: 0.0858
# Validation accuracy: 0.9667
# Epoch 56/100: Train Loss: 0.0659
# Validation loss: 0.0854
# Validation accuracy: 0.9667
# Epoch 57/100: Train Loss: 0.0653
# Validation loss: 0.0849
# Validation accuracy: 0.9667
# Epoch 58/100: Train Loss: 0.0647
# Validation loss: 0.0845
# Validation accuracy: 0.9667
# Epoch 59/100: Train Loss: 0.0641
# Validation loss: 0.0841
# Validation accuracy: 0.9667
# Epoch 60/100: Train Loss: 0.0635
# Validation loss: 0.0837
# Validation accuracy: 0.9667
# Epoch 61/100: Train Loss: 0.0629
# Validation loss: 0.0833
# Validation accuracy: 0.9667
# Epoch 62/100: Train Loss: 0.0624
# Validation loss: 0.0830
# Validation accuracy: 0.9667
# Epoch 63/100: Train Loss: 0.0618
# Validation loss: 0.0827
# Validation accuracy: 0.9667
# Epoch 64/100: Train Loss: 0.0613
# Validation loss: 0.0823
# Validation accuracy: 0.9667
# Epoch 65/100: Train Loss: 0.0608
# Validation loss: 0.0820
# Validation accuracy: 0.9667
# Epoch 66/100: Train Loss: 0.0603
# Validation loss: 0.0817
# Validation accuracy: 0.9667
# Epoch 67/100: Train Loss: 0.0599
# Validation loss: 0.0814
# Validation accuracy: 0.9667
# Epoch 68/100: Train Loss: 0.0594
# Validation loss: 0.0812
# Validation accuracy: 0.9667
# Epoch 69/100: Train Loss: 0.0590
# Validation loss: 0.0809
# Validation accuracy: 0.9667
# Epoch 70/100: Train Loss: 0.0586
# Validation loss: 0.0806
# Validation accuracy: 0.9667
# Epoch 71/100: Train Loss: 0.0582
# Validation loss: 0.0804
# Validation accuracy: 0.9667
# Epoch 72/100: Train Loss: 0.0578
# Validation loss: 0.0802
# Validation accuracy: 0.9667
# Epoch 73/100: Train Loss: 0.0574
# Validation loss: 0.0799
# Validation accuracy: 0.9667
# Epoch 74/100: Train Loss: 0.0570
# Validation loss: 0.0797
# Validation accuracy: 0.9667
# Epoch 75/100: Train Loss: 0.0566
# Validation loss: 0.0795
# Validation accuracy: 0.9667
# Epoch 76/100: Train Loss: 0.0563
# Validation loss: 0.0793
# Validation accuracy: 0.9667
# Epoch 77/100: Train Loss: 0.0559
# Validation loss: 0.0791
# Validation accuracy: 0.9667
# Epoch 78/100: Train Loss: 0.0556
# Validation loss: 0.0789
# Validation accuracy: 0.9667
# Epoch 79/100: Train Loss: 0.0552
# Validation loss: 0.0787
# Validation accuracy: 0.9667
# Epoch 80/100: Train Loss: 0.0549
# Validation loss: 0.0786
# Validation accuracy: 0.9667
# Epoch 81/100: Train Loss: 0.0546
# Validation loss: 0.0784
# Validation accuracy: 0.9667
# Epoch 82/100: Train Loss: 0.0543
# Validation loss: 0.0782
# Validation accuracy: 0.9667
# Epoch 83/100: Train Loss: 0.0540
# Validation loss: 0.0781
# Validation accuracy: 0.9667
# Epoch 84/100: Train Loss: 0.0537
# Validation loss: 0.0779
# Validation accuracy: 0.9667
# Epoch 85/100: Train Loss: 0.0534
# Validation loss: 0.0778
# Validation accuracy: 0.9667
# Epoch 86/100: Train Loss: 0.0531
# Validation loss: 0.0777
# Validation accuracy: 0.9667
# Epoch 87/100: Train Loss: 0.0529
# Validation loss: 0.0775
# Validation accuracy: 0.9667
# Epoch 88/100: Train Loss: 0.0526
# Validation loss: 0.0774
# Validation accuracy: 0.9667
# Epoch 89/100: Train Loss: 0.0523
# Validation loss: 0.0773
# Validation accuracy: 0.9667
# Epoch 90/100: Train Loss: 0.0521
# Validation loss: 0.0772
# Validation accuracy: 0.9667
# Epoch 91/100: Train Loss: 0.0518
# Validation loss: 0.0770
# Validation accuracy: 0.9667
# Epoch 92/100: Train Loss: 0.0516
# Validation loss: 0.0769
# Validation accuracy: 0.9667
# Epoch 93/100: Train Loss: 0.0513
# Validation loss: 0.0768
# Validation accuracy: 0.9667
# Epoch 94/100: Train Loss: 0.0511
# Validation loss: 0.0767
# Validation accuracy: 0.9667
# Epoch 95/100: Train Loss: 0.0509
# Validation loss: 0.0766
# Validation accuracy: 0.9667
# Epoch 96/100: Train Loss: 0.0506
# Validation loss: 0.0765
# Validation accuracy: 0.9667
# Epoch 97/100: Train Loss: 0.0504
# Validation loss: 0.0764
# Validation accuracy: 0.9667
# Epoch 98/100: Train Loss: 0.0502
# Validation loss: 0.0763
# Validation accuracy: 0.9667
# Epoch 99/100: Train Loss: 0.0500
# Validation loss: 0.0762
# Validation accuracy: 0.9667
# Epoch 100/100: Train Loss: 0.0498
# Validation loss: 0.0762
# Validation accuracy: 0.9667
